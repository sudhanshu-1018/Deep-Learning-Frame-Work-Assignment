# %%
                                                    # Deep Learning Frameworks

# %%
# 1. What is TensorFlow 2.0, and how is it different from TensorFlow 1.x?
"""
Tensor space refers to the multi-dimensional arrays used in TensorFlow. All the data and computations in TensorFlow are handled using tensors.
They are important because they allow efficient computation, especially when using GPUs and TPUs.
"""

# %%
# 2. How do you install TensorFlow 2.0?
"""
pip install tensorflow
"""

# %%
# 3. What is the primary function of the tf.function in TensorFlow 2.0?
"""
The tf.function is used to convert a normal Python function into a TensorFlow graph. This makes the code run faster and more efficiently
because TensorFlow can optimize the execution.
"""

# %%
# 4. What is the purpose of the Model class in TensorFlow 2.0?
"""
The Model class is used to create and manage neural networks. It helps in defining the structure of the model, training the model, testing it,
and making predictions.It acts as the main component for deep learning tasks.
"""

# %%
# 5. How do you create a neural network using TensorFlow 2.0?

from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Dense(32, activation='relu', input_shape=(10,)),
    layers.Dense(1)
])

# %%
# 6. What is the importance of Tensor Space in TensorFlow?
"""
Tensor space refers to the multi-dimensional arrays used in TensorFlow. All the data and computations in TensorFlow are handled using tensors.
They are important because they allow efficient computation, especially when using GPUs and TPUs.
"""

# %%
# 7. How can TensorBoard be integrated with TensorFlow 2.0?

from tensorflow.keras.callbacks import TensorBoard
model.fit(X, y, epochs=5, callbacks=[TensorBoard(log_dir="logs")])

# %%
# 8. What is the purpose of TensorFlow Playground?
"""
TensorFlow Playground is an online tool used to understand how neural networks work.
It allows users to experiment with different parameters and visualize how the model learns.
"""

# %%
# 9. What is Netron, and how is it useful for deep learning models?
"""
Netron is a tool used to visualize deep learning models.
It helps in understanding the structure and layers of a model in a graphical way.
"""

# %%
# 10. What is the difference between TensorFlow and PyTorch?
"""
TensorFlow is widely used for production and deployment, while PyTorch is more popular in research because it is more flexible.
PyTorch uses dynamic graphs by default,while TensorFlow supports both static and dynamic execution.
"""

# %%
# 11. How do you install PyTorch?
"""
pip install torch
"""

# %%
# 12. What is the basic structure of a PyTorch neural network?
"""
In PyTorch, a neural network is created by defining a class that inherits from nn.Module.
Inside this class, layers are defined and a forward function is written to describe how data flows through the network.
"""

# %%
# 13. What is the significance of tensors in PyTorch?
"""
Tensors are the main data structure in PyTorch. They are used to store data and perform all computations.
They also support GPU acceleration which makes training faster.
"""

# %%
# 14. What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch?
"""
The torch.Tensor is stored in CPU memory, while torch.cuda.Tensor is stored in GPU memory. GPU tensors allow faster computation.
"""

# %%
# 15. What is the purpose of the torch.optim module in PyTorch?
"""
The torch.optim module is used to update model parameters during training. It provides optimization algorithms like SGD and Adam.
"""

# %%
# 16. What are some common activation functions used in neural networks?
"""
Activation functions are used to introduce non-linearity in neural networks. Some common ones are ReLU, Sigmoid, Tanh, and Softmax.
"""

# %%
# 17. What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch?
"""
nn.Module is used to create custom models with more flexibility, while nn.Sequential is used to create simple models by stacking layers in order.
"""

# %%
# 18. How can you monitor training progress in TensorFlow 2.0?
"""
Training progress can be monitored using TensorBoard or by plotting the loss and accuracy values during training.
"""

# %%
# 19. How does the Keras API fit into TensorFlow 2.0?
"""
Keras is the high-level API in TensorFlow 2.0 which makes model building easy. It provides simple functions to create, train, and evaluate models.
"""

# %%
# 20. What is an example of a deep learning project that can be implemented using TensorFlow 2.0?
"""
An example project is image classification, such as identifying handwritten digits or detecting objects in images.
"""

# %%
# 21. What is the main advantage of using pre-trained models in TensorFlow and PyTorch?
"""
Pre-trained models save time and effort because they are already trained on large datasets. They give better performance even with less data.
"""

# %%
                                                        # Practical

# %%
# 1. How do you install and verify that TensorFlow 2.0 was installed successfully?

pip install tensorflow

import tensorflow as tf
print(tf.__version__)

# %%
# 2. How can you define a simple function in TensorFlow 2.0 to perform addition?

import tensorflow as tf

@tf.function
def add(a, b):
    return a + b

print(add(2, 3))

# %%
# 3. How can you create a simple neural network in TensorFlow 2.0 with one hidden layer?

from tensorflow.keras import models, layers

model = models.Sequential([
    layers.Dense(10, activation='relu', input_shape=(5,)),
    layers.Dense(1)
])

# %%
# 4. How can you visualize the training progress using TensorFlow and Matplotlib?

history = model.fit(X, y, epochs=5)

import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.show()

# %%
# 5. How do you install PyTorch and verify the PyTorch installation?

pip install torch

import torch
print(torch.__version_

# %%
# 6. How do you create a simple neural network in PyTorch?

import torch.nn as nn

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc = nn.Linear(5, 1)

    def forward(self, x):
        return self.fc(x)

# %%
# 7. How do you define a loss function and optimizer in PyTorch?

import torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 8. How do you implement a custom loss function in PyTorch?

def custom_loss(output, target):
    return ((output - target) ** 2).mean()

# %%
# 9. How do you save and load a TensorFlow model?

model.save("model.h5")

from tensorflow.keras.models import load_model
model = load_model("model.h5")
